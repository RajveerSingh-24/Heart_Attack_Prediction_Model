# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Data (from preprocessed SQL or CSV)
df = pd.read_csv("X_train.csv")  # For visualizations only
df['HeartDisease'] = pd.read_csv("y_train.csv")

df.head()
# Out:
#         Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0  1.006537    1              1   0.356867     0.166481          1
# 1  0.157954    1              1  -1.210356     0.139040          1
# 2  0.582246    0              0  -0.129513     1.273277          1
# 3 -0.690629    1              0   1.491752    -1.818435          0
# 4 -0.372411    1              0   0.681120    -1.818435          1
#
#    RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease
# 0           2 -0.346192               1  0.293283         1             1
# 1           2  1.697314               0 -0.457194         2             0
# 2           2 -0.267596               1  0.574711         1             1
# 3           1 -0.503385               1 -0.832432         1             1
# 4           1  0.086088               1 -0.175765         1             1

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             734 non-null    float64
#  1   Sex             734 non-null    int64
#  2   ChestPainType   734 non-null    int64
#  3   RestingBP       734 non-null    float64
#  4   Cholesterol     734 non-null    float64
#  5   FastingBS       734 non-null    int64
#  6   RestingECG      734 non-null    int64
#  7   MaxHR           734 non-null    float64
#  8   ExerciseAngina  734 non-null    int64
#  9   Oldpeak         734 non-null    float64
#  10  ST_Slope        734 non-null    int64
#  11  HeartDisease    734 non-null    int64
# dtypes: float64(5), int64(7)
# memory usage: 68.9 KB
# None
#               Age         Sex  ChestPainType   RestingBP  Cholesterol  \
# count  734.000000  734.000000     734.000000  734.000000   734.000000
# ...

# %%
# Plot Categorical Feature Distributions
categorical_cols = ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']

for col in categorical_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=col, data=df)
    plt.title(f"{col} Distribution")
    plt.show()

# %%
# Plot Numerical Feature Distributions
numerical_cols = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']

for col in numerical_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"{col} Distribution")
    plt.show()

# %%
# Boxplots for Outliers
for col in numerical_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
# Compare Features with Target
for col in categorical_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=col, hue='HeartDisease', data=df)
    plt.title(f"{col} vs HeartDisease")
    plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
